# %% [markdown]
# <a href="https://colab.research.google.com/github/isaiastrajano/BootCamp_Python_DataScience/blob/main/Exerc%C3%ADcios_matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# Exercício 1

# %%
x = np.arange(-5.0, 5.0, 0.01)
y = np.sin(np.pi*x)

# %%
plt.plot(x, y)
plt.title("título")
plt.xlabel("eixo x")
plt.ylabel("eixo y")
plt.show()

# %% [markdown]
# Exerxicio 2

# %%
x = np.arange(20)
y = np.random.randint(1, 100, 20)

# %%
plt.plot(x, y, marker = 'o', color = 'black')
plt.title("Título")
plt.xlabel("eixo x")
plt.ylabel("eixo y")
plt.show()

# %% [markdown]
# Exercicio 3

# %%
y = np.random.normal(100, 5, 20)

# %%
plt.plot(x, y, marker = 'o', color = 'red', linestyle = '--')
plt.title("Título")
plt.xlabel("eixo x")
plt.ylabel("eixo y")
plt.show()

# %% [markdown]
# Exercício 4

# %%
n = 100
columns = ['Brand '+str(number) for number in range(1,5)]
date = pd.date_range(start = '2021-1-1', periods = n)
data = np.random.randint(low = 1, high = [100, 330, 45, 77], size = (n, 4))
df = pd.DataFrame(data,columns = columns, index = date)

# %%
df
# Out:
#             Brand 1  Brand 2  Brand 3  Brand 4
# 2021-01-01       55      176       44        1
# 2021-01-02       61      212       43       54
# 2021-01-03       42      306       40       45
# 2021-01-04       28      164       39       24
# 2021-01-05       71      147        1       41
# ...             ...      ...      ...      ...
# 2021-04-06       47       87       19       48
# 2021-04-07       39      152       44       62
# 2021-04-08       80      274       38       14
# 2021-04-09       19       45       23       59
# 2021-04-10       96      303        5       73
#
# [100 rows x 4 columns]

# %%
brand1 = df['Brand 1']

# %%
plt.figure(figsize = (20, 5))
#plt.plot(df.index, df['Brand 1'], color = 'black') resposta do exercício
plt.plot(date, brand1, color = 'black')
#foi colocado no argumento de x 'df.index', mas poderia ter sido 'data'
#foi selecionado a coluna dentro do argumento, mas a opção anterior atribuia a uma variável a coluna e utilizaria a variável
plt.title("Brand 1")
plt.xlabel("Data")
plt.ylabel("Values")
plt.show()

# %% [markdown]
# Exercicio 5

# %%
df.sum()
# Out:
# Brand 1     5020
# Brand 2    18826
# Brand 3     2356
# Brand 4     3919
# dtype: int64

# %%
sum = pd.DataFrame(df.sum())
sum
# Out:
#              0
# Brand 1   5020
# Brand 2  18826
# Brand 3   2356
# Brand 4   3919

# %%
plt.figure(figsize = (15, 5))
#plt.plot(df.index, df['Brand 1'], color = 'black') resposta do exercício
plt.bar(columns, df.sum(), color = 'blue', align = 'center')
#foi colocado no argumento de x 'df.index', mas poderia ter sido 'data'
#foi selecionado a coluna dentro do argumento, mas a opção anterior atribuia a uma variável a coluna e utilizaria a variável
plt.title("Somatório de Brands")
plt.xlabel("Brand")
plt.ylabel("Values")
plt.show()

# %% [markdown]
# Exercicio 6

# %%
plt.figure(figsize = (10, 5))
#plt.plot(df.index, df['Brand 1'], color = 'black') resposta do exercício
plt.barh(columns, df.sum(), color = 'blue', align = 'center')
#foi colocado no argumento de x 'df.index', mas poderia ter sido 'data'
#foi selecionado a coluna dentro do argumento, mas a opção anterior atribuia a uma variável a coluna e utilizaria a variável
plt.title("Somatório de Brands")
plt.xlabel("Brand")
plt.ylabel("Values")
plt.show()

# %% [markdown]
# Exercício 7

# %%
    from sklearn.datasets import make_regression
    X, y = make_regression(n_samples = 100, n_features = 1, noise = 10)

# %%
plt.scatter(X, y, marker = '^', alpha = 0.3, color = 'black')
plt.grid(True, linestyle = '--')
plt.title('Relashionhip between X and y')
plt.xlabel('Feature')
plt.ylabel('Target')
# Out:
# Text(0, 0.5, 'Target')

# %% [markdown]
# Exercício 8

# %%
data = np.random.normal(loc = 100, scale = 0.5, size = 100)

# %%
plt.hist(x = data)
plt.title('Histogram', color = 'k')
plt.xlabel('Data')
plt.show()

# %% [markdown]
# Exercício 9

# %%
x = np.arange(1,11)
y1 = x**2
y2 = x**3
y3 = x**4

# %%
plt.scatter(x, y1, marker = 'o')
plt.scatter(x, y2, marker = '^')
plt.scatter(x, y3, marker = '*')
plt.title('Values')
plt.xlabel('X')
plt.ylabel('Y')
plt.grid(True, linestyle = '--')
plt.legend(['y1','y2', 'y3'], title = "Legend")
plt.show()

# %% [markdown]
# Exercício 10

# %%
    brand_A = [120, 130, 145, 177, 270, 211]
    brand_B = [90, 41, 140, 150, 230, 193]
    months = ['January','February','March','April','May','June']

# %%
plt.figure(figsize = (5, 5))
plt.bar(months, brand_A, color = 'blue')
plt.bar(months, brand_B, color = 'red')
plt.title("Somatório de Brands")
plt.xlabel("Brand")
plt.ylabel("Values")
plt.savefig(fname = 'Figura', transparent = False)
plt.show()

# %%
#referencia aleatória
plt.figure(figsize = (10,10)) #tamanho do gráfico
plt.scatter(x,y, color = 'green', label = 'Exemplo de legenda')
#plotando o tipo do gráfico e os argumentos de configuração
plt.title("título") #alterando titulo
plt.grid(True) # incluir uma grade ao fundo da figura
plt.legend() #plotar uma legenda
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-56-1f157784b263> in <module>()
#       1 #referencia aleatória
#       2 plt.figure(figsize = (10,10)) #tamanho do gráfico
# ----> 3 plt.scatter(x,y, color = 'green', label = 'Exemplo de legenda')
#       4 #plotando o tipo do gráfico e os argumentos de configuração
#       5 plt.title("título") #alterando titulo
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, data, **kwargs)
#    2814         verts=verts, edgecolors=edgecolors,
#    2815         plotnonfinite=plotnonfinite, **({"data": data} if data is not
# -> 2816         None else {}), **kwargs)
#    2817     sci(__ret)
#    2818     return __ret
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1563     def inner(ax, *args, data=None, **kwargs):
#    1564         if data is None:
# -> 1565             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1566
#    1567         bound = new_sig.bind(ax, *args, **kwargs)
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/cbook/deprecation.py in wrapper(*args, **kwargs)
#     356                 f"%(removal)s.  If any parameter follows {name!r}, they "
#     357                 f"should be pass as keyword, not positionally.")
# --> 358         return func(*args, **kwargs)
#     359
#     360     return wrapper
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/axes/_axes.py in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, **kwargs)
#    4389         y = np.ma.ravel(y)
#    4390         if x.size != y.size:
# -> 4391             raise ValueError("x and y must be the same size")
#    4392
#    4393         if s is None:
#
# ValueError: x and y must be the same size
